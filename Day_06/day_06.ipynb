# %%
import numpy as np
import pandas as pd

# %%
country = ['India', 'Pakistan', 'Usa', 'Qatar']
pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         Usa
# 3       Qatar
# dtype: str

# %%
marks = [12,23,34,45,56]
subjects = [' English', 'Math', 'Physics', 'Urdu', 'Science']
pd.Series(subjects, index=marks)
# Out:
# 12     English
# 23        Math
# 34     Physics
# 45        Urdu
# 56     Science
# dtype: str

# %%
marks = {
    'maths' : 67,
    'english' : 76,
    'urdu' : 87
}
marks_series = pd.Series(marks, name='Hamza k marks')
marks_series
# Out:
# maths      67
# english    76
# urdu       87
# Name: Hamza k marks, dtype: int64

# %%
sub = pd.read_csv('subs.csv', index_col=0).squeeze("columns")

# %%
kohli_runs = pd.read_csv('kohli_ipl.csv', index_col='match_no').squeeze("columns")

# %%
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp.count()
# Out:
# np.int64(7)

# %%
temp.size
# Out:
# 10

# %%
kohli_runs.isna().sum()
# Out:
# np.int64(0)

# %%
temp.fillna(temp.mean())
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     5.0
# 4     5.0
# 5     6.0
# 6     5.0
# 7     8.0
# 8     5.0
# 9    10.0
# dtype: float64

# %%
kohli_runs[kohli_runs.isin([49,99])]
# Out:
# Series([], Name: runs, dtype: int64)

# %%
movies = pd.read_csv('bollywood.csv')

# %%
movies.apply(lambda x: x.split()[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 movies.apply(lambda x: x.split()[0])
#
# File c:\Users\Hamza\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:12435, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   12431                 engine_kwargs=engine_kwargs,
#   12432                 args=args,
#   12433                 kwargs=kwargs,
#   12434             )
# > 12435             return op.apply().__finalize__(self, method="apply")
#   12436         elif hasattr(engine, "__pandas_udf__"):
#   12437             if result_type is not None:
#   12438                 raise NotImplementedError(
#
# File c:\Users\Hamza\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\apply.py:1015, in FrameApply.apply(self)
#    1012 elif self.raw:
# ...

# %%
new = kohli_runs.head().copy()

# %%
new
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
new[1] = 100

# %%
kohli_runs.head()
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
new
# Out:
# match_no
# 1    100
# 2     23
# 3     13
# 4     12
# 5      1
# Name: runs, dtype: int64

# %%
kohli_runs[kohli_runs.between(50,100)].shape[0]
# Out:
# 3

# %%
kohli_runs[kohli_runs.between(30,50)]
# Out:
# match_no
# 7     34
# 12    38
# 15    50
# 21    32
# Name: runs, dtype: int64

# %%
kohli_runs.shape[0]
# Out:
# 30

# %%
subs = pd.read_csv('subs.csv')

# %%
subs.clip(100,200)
# Out:
# ---------------------------------------------------------------------------
# ArrowNotImplementedError                  Traceback (most recent call last)
# File c:\Users\Hamza\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\arrays\arrow\array.py:944, in ArrowExtensionArray._cmp_method(self, other, op)
#     943 try:
# --> 944     result = pc_func(self._pa_array, self._box_pa(other))
#     945 except (pa.lib.ArrowNotImplementedError, pa.lib.ArrowInvalid):
#
# File c:\Users\Hamza\AppData\Local\Programs\Python\Python314\Lib\site-packages\pyarrow\compute.py:254, in _make_generic_wrapper.<locals>.wrapper(memory_pool, *args)
#     253     return Expression._call(func_name, list(args))
# --> 254 return func.call(args, None, memory_pool)
#
# File pyarrow/_compute.pyx:399, in pyarrow._compute.Function.call()
# --> 399 'Could not get source, probably due dynamically evaluated source code.'
#
# File pyarrow/error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
# ...
