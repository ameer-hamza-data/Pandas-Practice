# %%
import numpy as np
import pandas as pd

# %%
# country = ['India', 'pakistan', 'USA', 'Nepal', 'Srilanka']
# pd.Series(country)
country = ['Hamza', 'Umar', 'Usman', 'Bilal', 'Shabeer']
pd.Series(country)
# Out:
# 0      Hamza
# 1       Umar
# 2      Usman
# 3      Bilal
# 4    Shabeer
# dtype: str

# %%
# runs = [13,24,56,78,100]
# runs_ser = pd.Series(runs)
runs = [13,23,45,56,78,90]
runs_per= pd.Series(runs)
runs_per
# Out:
# 0    13
# 1    23
# 2    45
# 3    56
# 4    78
# 5    90
# dtype: int64

# %%
# marks = [67,57,89,100]
# subjects= ['maths', 'english', 'science', 'Urdu']
# pd.Series(marks, index=subjects)
marks = [12,34,56,76,78,89]
subjects = ['English', 'Maths', 'Urdu', 'Science','Sindhi', 'Islamiat']
pd.Series(marks, index=subjects)
# Out:
# English     12
# Maths       34
# Urdu        56
# Science     76
# Sindhi      78
# Islamiat    89
# dtype: int64

# %%
# marks = pd.Series(marks, index=subjects, name='Hamza marks')
# marks
marks = pd.Series(marks, index=sun)
# Out:
# maths       67
# english     57
# science     89
# Urdu       100
# Name: Hamza marks, dtype: int64

# %%
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'Urdu':100
}
marks_series= pd.Series(marks, name='Hamza k marks')
marks_series
# Out:
# maths       67
# english     57
# science     89
# Urdu       100
# Name: Hamza k marks, dtype: int64

# %%
marks_series.size
# Out:
# 4

# %%
marks_series.dtype
# Out:
# dtype('int64')

# %%
marks_series.name
# Out:
# 'Hamza k marks'

# %%
marks_series.is_unique
# Out:
# True

# %%
marks_series.index
# Out:
# Index(['maths', 'english', 'science', 'Urdu'], dtype='str')

# %%
runs_ser.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %%
# subs = pd.read_csv('subs.csv', squeeze=True)
# sub = pd.read_csv('subs.csv', index_col=0).squeeze=('column')
sub = pd.read_csv('subs.csv', index_col=0).squeeze("columns")
print(type(sub))
print(sub.shape)
print(sub)
# Out:
# <class 'pandas.Series'>
# (30,)
# Date
# 2022-03-05    48
# 2022-03-06    57
# 2022-03-07    40
# 2022-03-08    53
# 2022-03-09    63
# 2022-03-10    45
# 2022-03-11    36
# 2022-03-12    72
# 2022-03-13    65
# 2022-03-14    58
# 2022-03-15    41
# 2022-03-16    69
# 2022-03-17    77
# 2022-03-18    50
# 2022-03-19    44
# 2022-03-20    39
# 2022-03-21    61
# 2022-03-22    55
# 2022-03-23    48
# 2022-03-24    70
# 2022-03-25    66
# 2022-03-26    52
# 2022-03-27    47
# 2022-03-28    60
# 2022-03-29    49
# 2022-03-30    73
# 2022-03-31    68
# 2022-04-01    56
# 2022-04-02    42
# 2022-04-03    38
# Name: Subscribers gained, dtype: int64

# %%
type(sub)
# Out:
# str

# %%
kohli_runs = pd.read_csv('kohli_ipl.csv', index_col='match_no').squeeze("columns")
kohli_runs.head()
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
kohli_runs.name
# Out:
# 'runs'

# %%
movies = pd.read_csv('bollywood.csv', index_col='movie').squeeze('columns')

# %%
movies.sample(9)
# Out:
# movie
# Uri: The Surgical Strike           Vicky Kaushal
# Tanhaji                               Ajay Devgn
# Zero                              Shah Rukh Khan
# Student of the Year 2               Tiger Shroff
# Gully Boy                          Ranveer Singh
# Good Newwz                          Akshay Kumar
# Kalank                                Alia Bhatt
# Soni                        Geetika Vidya Ohlyan
# Street Dancer 3D                    Varun Dhawan
# Name: lead, dtype: str

# %%
movies.value_counts()
# Out:
# lead
# Akshay Kumar            3
# Kangana Ranaut          2
# Ranveer Singh           2
# Tiger Shroff            2
# Vicky Kaushal           1
# Vicky Ahuja             1
# Anupam Kher             1
# Emraan Hashmi           1
# Mona Ambegaonkar        1
# Geetika Vidya Ohlyan    1
# Arshad Warsi            1
# Shah Rukh Khan          1
# Alia Bhatt              1
# Hrithik Roshan          1
# Sushant Singh Rajput    1
# Sidharth Malhotra       1
# Ayushmann Khurrana      1
# Ajay Devgn              1
# Varun Dhawan            1
# Irrfan Khan             1
# Name: count, dtype: int64

# %%
kohli_runs.sort_values(ascending=False).head(1).values[0]
# Out:
# np.int64(63)

# %%
kohli_runs.sort_values(inplace=True)

# %%
kohli_runs.head(6)
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# 6     9
# Name: runs, dtype: int64

# %%
movies.head()
# Out:
# movie
# Uri: The Surgical Strike            Vicky Kaushal
# Battalion 609                         Vicky Ahuja
# The Accidental Prime Minister         Anupam Kher
# Why Cheat India                     Emraan Hashmi
# Evening Shadows                  Mona Ambegaonkar
# Name: lead, dtype: str

# %%
movies.sort_index()
# Out:
# movie
# Angrezi Medium                               Irrfan Khan
# Baaghi 3                                    Tiger Shroff
# Bala                                  Ayushmann Khurrana
# Battalion 609                                Vicky Ahuja
# Chhichhore                          Sushant Singh Rajput
# Evening Shadows                         Mona Ambegaonkar
# Fraud Saiyaan                               Arshad Warsi
# Good Newwz                                  Akshay Kumar
# Gully Boy                                  Ranveer Singh
# Housefull 4                                 Akshay Kumar
# Kalank                                        Alia Bhatt
# Kesari                                      Akshay Kumar
# Manikarnika: The Queen of Jhansi          Kangana Ranaut
# Marjaavaan                             Sidharth Malhotra
# Panga                                     Kangana Ranaut
# Simmba                                     Ranveer Singh
# ...

# %%
kohli_runs.count()
# Out:
# np.int64(30)

# %%
sub
# Out:
# Date
# 2022-03-05    48
# 2022-03-06    57
# 2022-03-07    40
# 2022-03-08    53
# 2022-03-09    63
# 2022-03-10    45
# 2022-03-11    36
# 2022-03-12    72
# 2022-03-13    65
# 2022-03-14    58
# 2022-03-15    41
# 2022-03-16    69
# 2022-03-17    77
# 2022-03-18    50
# 2022-03-19    44
# 2022-03-20    39
# 2022-03-21    61
# 2022-03-22    55
# 2022-03-23    48
# 2022-03-24    70
# 2022-03-25    66
# 2022-03-26    52
# 2022-03-27    47
# 2022-03-28    60
# 2022-03-29    49
# 2022-03-30    73
# 2022-03-31    68
# 2022-04-01    56
# 2022-04-02    42
# 2022-04-03    38
# Name: Subscribers gained, dtype: int64

# %%
sub.sum()
# Out:
# np.int64(1642)

# %%
sub.mean()
print(kohli_runs.median())
# Out:
# 14.0

# %%
print(movies.mode())
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: str

# %%
import pandas as pd 
import numpy as np

# %%
sub = pd.read_csv('subs.csv')
vk = pd.read_csv('kohli_ipl.csv')
movies = pd.read_csv('bollywood.csv')

# %%
print(vk.median())
print(movies.mode())
# print(sub.std())
print(vk.var())
# Out:
# match_no    15.5
# runs        14.0
# dtype: float64
#                                movie          lead
# 0                     Angrezi Medium  Akshay Kumar
# 1                           Baaghi 3           NaN
# 2                               Bala           NaN
# 3                      Battalion 609           NaN
# 4                         Chhichhore           NaN
# 5                    Evening Shadows           NaN
# 6                      Fraud Saiyaan           NaN
# 7                         Good Newwz           NaN
# 8                          Gully Boy           NaN
# 9                        Housefull 4           NaN
# 10                            Kalank           NaN
# 11                            Kesari           NaN
# 12  Manikarnika: The Queen of Jhansi           NaN
# 13                        Marjaavaan           NaN
# 14                             Panga           NaN
# 15                            Simmba           NaN
# ...

# %%
sub.min()
# Out:
# Date                  2022-03-05
# Subscribers gained            36
# dtype: object

# %%
sub.max()
# Out:
# Date                  2022-04-03
# Subscribers gained            77
# dtype: object

# %%
vk.describe()
# Out:
#         match_no       runs
# count  30.000000  30.000000
# mean   15.500000  18.233333
# std     8.803408  16.521007
# min     1.000000   0.000000
# 25%     8.250000   5.250000
# 50%    15.500000  14.000000
# 75%    22.750000  24.500000
# max    30.000000  63.000000

# %%
x = pd.Series([12,34,45,56,78,89,90])
x[2]
# Out:
# np.int64(45)

# %%
bollywood = pd.read_csv('bollywood.csv', index_col=0).squeeze("columns")

# %%
bollywood.iloc[3]
# Out:
# movie    Why Cheat India
# lead       Emraan Hashmi
# Name: 3, dtype: str

# %%
bollywood = pd.read_csv('bollywood.csv')

# %%
bollywood.iloc[0:5]
# Out:
#                            movie              lead
# 0       Uri: The Surgical Strike     Vicky Kaushal
# 1                  Battalion 609       Vicky Ahuja
# 2  The Accidental Prime Minister       Anupam Kher
# 3                Why Cheat India     Emraan Hashmi
# 4                Evening Shadows  Mona Ambegaonkar

# %%
bollywood.iloc[::4]
# Out:
#                        movie              lead
# 0   Uri: The Surgical Strike     Vicky Kaushal
# 4            Evening Shadows  Mona Ambegaonkar
# 8                     Simmba     Ranveer Singh
# 12                    Kalank        Alia Bhatt
# 16               Housefull 4      Akshay Kumar
# 20                   Tanhaji        Ajay Devgn
# 24            Angrezi Medium       Irrfan Khan

# %%
vk.head()
# Out:
#    match_no  runs
# 0         1     1
# 1         2    23
# 2         3    13
# 3         4    12
# 4         5     1

# %%
vk = pd.read_csv('kohli_ipl.csv', index_col=0).squeeze("columns")

# %%
vk[[1,3,4]]
# Out:
# match_no
# 1     1
# 3    13
# 4    12
# Name: runs, dtype: int64

# %%
bollywood.iloc[[1,4,5]]
# Out:
#              movie                  lead
# 1    Battalion 609           Vicky Ahuja
# 4  Evening Shadows      Mona Ambegaonkar
# 5             Soni  Geetika Vidya Ohlyan

# %%
marks_series
# Out:
# maths       67
# english     57
# science     89
# Urdu       100
# Name: Hamza k marks, dtype: int64

# %%
marks_series[1] = 100
marks_series['english'] = 100
marks_series
# Out:
# maths       67
# english    100
# science     89
# Urdu       100
# 1          100
# Name: Hamza k marks, dtype: object

# %%
marks_series = marks_series.drop(marks_series.index[4])
marks_series
# Out:
# maths       67
# english    100
# science     89
# Urdu       100
# Name: Hamza k marks, dtype: object

# %%
marks_series['sst'] = 92
marks_series
# Out:
# maths       67
# english    100
# science     89
# Urdu       100
# sst         92
# Name: Hamza k marks, dtype: object

# %%
runs = [13,24,56,78,100]
runs_per = pd.Series(runs)
runs_per
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
# runs_per[[0:1]] = [70,75]
runs_per[[0, 3]] = [15, 80]
runs_per
# Out:
# 0     15
# 1     24
# 2     56
# 3     80
# 4    100
# dtype: int64

# %%
runs_per[[0,3,4]] = [0,0,0]
runs_per
# Out:
# 0     0
# 1    24
# 2    56
# 3     0
# 4     0
# dtype: int64

# %%
len(vk)
print(type(vk))
print(dir(vk))
print(sorted(vk))
print(min(vk))
print(max(vk))
# Out:
# <class 'pandas.Series'>
# ...

# %%
marks_series
list(marks_series)
dict(marks_series)
# Out:
# {'maths': 67, 'english': 100, 'science': 89, 'Urdu': 100, 'sst': 92}

# %%
print(marks_series)
print(dict(marks_series))
list(marks_series)
# Out:
# maths       67
# english    100
# science     89
# Urdu       100
# sst         92
# Name: Hamza k marks, dtype: object
# {'maths': 67, 'english': 100, 'science': 89, 'Urdu': 100, 'sst': 92}
# [67, 100, 89, 100, 92]

# %%
print('good')
# Out:
# good

# %%
print('jojo')
# Out:
# jojo

# %%
'''Hamza'''
# Out:
# 'Hamza'
